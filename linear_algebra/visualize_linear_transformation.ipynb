# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg

# %%
import plot_A
from plot_A import *

# %%
A = np.array([
    [-1., -3.],
    [4., 2.]
])
print('A = ',)
print(A)
# Out:
# A =
# [[-1. -3.]
#  [ 4.  2.]]

# %%
plot_A(A)

# %%
plot_A_abs(A)

# %%
A = np.array([
    [-1., 3.],
    [-2., 2.]
])
print('A = ',)
print(A)
print('shape of A =', A.shape)
# Out:
# A =
# [[-1.  3.]
#  [-2.  2.]]
# shape of A = (2, 2)

# %%
plot_A(A)

# %%
plot_A_abs(A)
