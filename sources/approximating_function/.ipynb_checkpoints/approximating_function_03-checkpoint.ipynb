# %% [markdown]
# # Section:  Approximating functions - Lecture 3
#
# ## [3] Interpolation error
#
# When interpolating a given function $f$ by a polynomial of degree $n$ at the nodes $x_0$, $\cdots$, $x_n$, it can be shown that we get the error
# $$f(x) - p(x) = f[x_0, \cdots, x_n, x] \prod^n_{i=0}(x-x_i),$$
# where $f[x_0, \cdots, x_n, x]$ is the notation for divided differences.
#
# So in principle, to have a "best" interpolation we should choose nodes such that
# $$\ell(x) = \prod^n_{i=0}(x-x_i)$$
# is minimized, i.e., such that $\displaystyle \left\|\ell(x)\right\|_{\infty}$ is smallest.
#
# In the following we use some examples to demonstrate the relation between the chosen nodes and the function $\ell(x)$. You will see that the Chebyshev nodes is the best.

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>
#
# #### Remark:
# We'll use packages LinearAlgebra for solving the polynomial and PyPlot for plotting. Run <code>using Pkg; Pkg.add("PyPlot")</code> if you don't have PyPlot installed.

# %%
using PyPlot
# Out:
# ┌ Info: Recompiling stale cache file /Users/tslin/.julia/compiled/v1.1/PyPlot/oatAj.ji for PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1184

# %% [markdown]
# We first define a function that plots the polynomial $P(x)$ for given nodes for later usage.

# %%
# a function that plots the corresponding polynomial with given nodes
function PlotPolynomial(x_nodes,labelstring="l(x)",l=1000::Int)
    # x: the nodes
    # l: length of the linsapce
    # labelstring: the label of the polynomial
    
    n=length(x_nodes);
    
    # construct the linspace
    xl = range(-1,stop=1,length=1000);
    
    # construct the polynomial
    p_nodes = xl .-x_nodes[1];
    for ii=1:n-1
        p_nodes = p_nodes.*(xl.-x_nodes[ii+1]);
    end
    
    # plot the polynomial
    plot(xl, p_nodes,label=labelstring);
    plot(x_nodes, zeros(n,1), "or");
    plt.legend();
    println("max. norm of "*labelstring*"=",maximum(abs.(p_nodes)));
end
# Out:
# PlotPolynomial (generic function with 3 methods)

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>
#
# ### [3.1] Random Nodes
# ### Example 1
#
# We first illustrate what happened if we simply choose random nodes on $[-1,1]$ to do the polynomial interpolation.
#
# We plot the polynomial $\displaystyle \ell(x)=\prod^n_{i=0}(x-x_i)$ when choosing $n+1$ random points on $[-1, 1]$ for $n=5$, $10$ and $20$.

# %%
# 2*rand(n+1).-1 gives n+1 random nodes for integer n
n=5;
PlotPolynomial(2*rand(n+1).-1);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.1226464866443966

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %%
n=10;
PlotPolynomial(2*rand(n+1).-1);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=3.0022289445264114

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %%
n=20;
PlotPolynomial(2*rand(n+1).-1);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.000319641068994856

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>
#
# ### [3.2] Equally spaced Nodes
#
# Now let's try uniformly distributed points on $[-1,1]$:
# $$x_k = -1 + 2\frac{k}{n}, \quad k=0,1,2,\cdots,n,$$
#
#
# ### Example 2
# We would like to plot the polynomial $\displaystyle \ell(x)=\prod^n_{i=0}(x-x_i)$ when choose $n+1$ equally spaced points on $[-1, 1]$ for $n=5$, $10$ and $20$.

# %%
# 2*(0:n)/n .-1  gives n+1 equally spaced nodes for integer n
n=5;
PlotPolynomial(2*(0:n)/n .-1);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.06922546010398747

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %%
n=10;
PlotPolynomial(2*(0:n)/n .-1);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.008530768039898246

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %%
n=20;
PlotPolynomial(2*(0:n)/n .-1);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.00023361682788821547

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %% [markdown]
# ### [3.3] Chebyshev Nodes of the first kind
#
# Consider chebychev nodes
# $$x_k = \cos\left(\frac{2k-1}{2n}\pi\right), \quad k=1,2,\cdots,n.$$
#
# ### Example 3
# We would like to plot the polynomial $\displaystyle \ell(x)=\prod^n_{i=1}(x-x_i)$ when choose $n$ Chebyshev Nodes of the first kind for $n=5$, $10$ and $20$.

# %%
# cos.(((1:n).-0.5)*pi/n) gives n Chebyshev nodes of the first kind for integrer n
n=5;
PlotPolynomial(cos.(((1:n).-0.5)*pi/n));
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.06250000000000008

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %%
n=10;
PlotPolynomial(cos.(((1:n).-0.5)*pi/n));
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.0019531250000000126

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %%
n=20;
PlotPolynomial(cos.(((1:n).-0.5)*pi/n));
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=1.907348632812514e-6

# %% [markdown]
# ### [3.35] Notes on Chebyshev Nodes of the first kind
#
# Consider polynomial interpolation of some function $f$ on $[-1, 1]$ using Chebyshev Nodes of the first kind:
# $$x_k = \cos\left(\frac{2k-1}{2n}\pi\right) \quad k=1,2,\cdots,n.$$
# Then, construct $\ell(x)$ by determinating the $n-1$ degree polynomial that has value $f(x_k)$ at $x_k$ for each $k$.
# One can prove that
# $$|f(x)-\ell(x)| \leq \frac{1}{2^{n-1}n!}\max_{\xi\in[-1,1]}|f^{n}(\xi)|,$$
# which gives us small error as $n$ become large.
#
# For more details one can read "Chebyshev nodes" in [wiki](https://en.wikipedia.org/wiki/Chebyshev_nodes).

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %% [markdown]
# ### [3.4] Chebyshev Nodes of the second kind
#
# Consider chebychev nodes of the second kind:
# $$x_k = \cos\left(\frac{k}{n}\pi\right), \quad k=0,1,2,\cdots,n.$$
#
# ### Example 4
# We would like to plot the polynomial $\displaystyle \ell(x)=\prod^n_{i=0}(x-x_i)$ when choose $n+1$ Chebyshev Nodes of the second kind for $n=5$, $10$ and $20$.

# %%
# cos.((0:n)*pi/n) gives the n+1 Chebyshev nodes of the second kind for integer n
n=5;
PlotPolynomial(cos.((0:n)*pi/n));
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.06249918587431625

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %%
n=10;
PlotPolynomial(cos.((0:n)*pi/n));
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=0.0019293110619113985

# %% [markdown]
# <div style="page-break-after: always; visibility: hidden">
# \pagebreak
# </div>

# %%
n=20;
PlotPolynomial(cos.((0:n)*pi/n));
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# max. norm of l(x)=1.9012283962444363e-6

# %% [markdown]
# ## Conclusion
#
# To summarize, we have seen that among all the strategies of choosing nodes, the Chebyshev nodes of the first kind seems perform best, and the Chebyshev nodes of the second kind performs OK as well, in the sense that as the number of points $n$ gets bigger, the maximum norm of $\ell(x)$ indeed decreases. The two other choices, random nodes and equally spaced nodes,
